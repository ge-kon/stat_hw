# %%
import pandas as pd, numpy as np, scipy.stats as sps, matplotlib.pyplot as plt

# %% [markdown]
# # Задача 1. Прокомментируй формулировки гипотез

# %% [markdown]
# Какие из формулировок ниже не являются гипотезами в контексте ситуации? Обоснуй свой ответ.

# %% [markdown]
# ##1. (blue, баллы: 0.7) Кандидат проходит техническое собеседование с задачами.
#
#   $H_0$: Кандидат решил 1 задачу из предложенных.
#
#   $H_1$: Кандидат решил больше 1 задачи из предложенных.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##2. (blue, баллы: 0.7) Кандидат проходит техническое собеседование с задачами.
#
#   $H_0$: Кандидат решает задачи уровня собеседования с вероятностью 90%.
#
#   $H_1$: С вероятностью 97%.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##3. (blue, баллы: 0.7) Клиент банка взял кредит.
#
#   $H_0$: Клиент ещё ни разу не возвращал кредиты.
#
#   $H_1$: Клиент уже возвращал кредиты раньше.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##4. (blue, баллы: 0.7) Клиент банка взял кредит.
#
#   $H_0$: Клиент с такой кредитной историей возвращает кредит с вероятностью 70%.
#
#   $H_1$: Клиент с такой кредитной историей возвращает кредит с вероятностью 90%.

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 2. Сформулируй статистические гипотезы

# %% [markdown]
# Для каждой ситуации определи, что является нулевой, а что альтернативной гипотезой, исходя из бизнес-логики. Объясни свой выбор.

# %% [markdown]
# ##1. (blue, баллы: 1) Есть две вероятностные модели поведения кандидата на собеседовании со смысловыми названиями «сильный кандидат» и «слабый кандидат». Дилемма: брать ли кандидата на работу.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##2. (blue, баллы: 1) Есть две вероятностные модели сотрудника на кассе со смысловыми названиями «кассир ворует» и «кассир не ворует». Дилемма: увольнять ли кассира.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##3. (red, баллы: 0.6) У текущего дизайна продающей страницы конверсия посетителя в продажу составляет $0.04$, у нового дизайна конверсия неизвестна и обозначена $p$. Дилемма: менять ли дизайн.

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 3. Определи, является ли способ принятия решения тестом

# %% [markdown]
# Для каждой ситуации определи, является ли способ принятия решения тестом. Если нет, объясни, почему.

# %% [markdown]
# ##1. (blue, баллы: 0.8) На собеседовании в компанию есть две модели кандидатов «сильный» и «слабый». Сильный решает задачи собеседования с вероятностью 95%, слабый — 90%.
#
#   Способ действовать: брать на работу сильных кандидатов и не брать слабых.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##2. (blue, баллы: 0.8) На собеседовании в компанию есть две модели кандидатов «сильный» и «слабый». Сильный решает задачи собеседования с вероятностью 95%, слабый — 90%.
#
#   Способ действовать: брать на работу кандидатов, решивших больше или равно 19 задач из 20.

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 4. Сравни тесты по их характеристикам
# Сравни тесты и прокомментируй, какой лучше. Если есть контекст, учитывай его.

# %% [markdown]
# ##1. (blue, баллы: 1) Без контекста. Если сравнить нельзя, объясни почему.
#   <table>
# <caption>
# Характеристики нескольких тестов одной и той же пары $H_0$ и $H_1$
# </caption>
#   <thead>
#     <tr>
#       <th>Тест</th>
#       <th>Уровень значимости</th>
#       <th>Мощность</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><b>Тест 1</b></td>
#       <td>$0.05$</td>
#       <td>$0.89$</td>
#     </tr>
#     <tr>
#       <td><b>Тест 2</b></td>
#       <td>$0.03$</td>
#       <td>$0.89$</td>
#     </tr>
#     <tr>
#       <td><b>Тест 3</b></td>
#       <td>$0.10$</td>
#       <td>$0.11$</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Решение**

# %% [markdown]
# ##2. (blue, баллы: 1) Без контекста. Если сравнить нельзя, объясни почему.
#   <table>
# <caption>
# Характеристики нескольких тестов одной и той же пары $H_0$ и $H_1$
# </caption>
#   <thead>
#     <tr>
#       <th>Тест</th>
#       <th>Уровень значимости</th>
#       <th>Мощность</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><b>Тест 1</b></td>
#       <td>$0.001$</td>
#       <td>$0.30$</td>
#     </tr>
#     <tr>
#       <td><b>Тест 2</b></td>
#       <td>$0.10$</td>
#       <td>$0.95$</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Решение**

# %% [markdown]
# ##3. (red, баллы: 0.6) Есть две вероятностных модели сотрудника на кассе со смысловыми названиями.
#
#   $H_0$ — «кассир не ворует», $H_1$ — «кассир ворует».
#
#   Дилемма: увольнять ли кассира.
#   <table>
# <caption>
# Характеристики нескольких тестов одной и той же пары $H_0$ и $H_1$
# </caption>
#   <thead>
#     <tr>
#       <th>Тест</th>
#       <th>Уровень значимости</th>
#       <th>Мощность</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><b>Тест 1</b></td>
#       <td>$0.001$</td>
#       <td>$0.30$</td>
#     </tr>
#     <tr>
#       <td><b>Тест 2</b></td>
#       <td>$0.10$</td>
#       <td>$0.95$</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 5. Проведи тест

# %% [markdown]
# Кандидат на собеседовании должен решить 20 задач на время. Слабый кандидат решает с вероятностью 90% и не решает либо неправильно решает с вероятностью 10%. Сильный — 95% и 5%.
#
# $H_0$ — слабый кандидат, $H_1$ — сильный кандидат.
#
# Статистический тест: «Отклонить нулевую гипотезу (взять на работу), если из 20 задач решил хотя бы 19».
#
# Известно, что Иван решил 18 задач.

# %% [markdown]
# ##1. (blue, баллы: 0.6) Проведи статистический тест для Ивана: какое решение о гипотезах будет принято?

# %% [markdown]
# **Решение**

# %% [markdown]
# ##2. (blue, баллы: 1) В чём разница между двумя фразами и какая из них верно отражает результаты теста?
#
#  - «Статистический тест показал, что Иван слабый кандидат».
#
#  - «Тест показал недостаточно статистических свидетельств того, что Иван сильный кандидат».

# %% [markdown]
# **Решение**

# %% [markdown]
# ##3. (red, баллы: 0.8) Найди уровень значимости теста.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##4. (red, баллы: 0.8) Найди мощность теста.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##5. (black, баллы: 1.2) Замени в тесте порог 19 задач. Подбери порог так, чтобы уровень значимости теста был не больше 10%, а мощность наибольшая. Какой порог и какая мощность получились?

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 6. Прокомментируй доверие результатам теста

# %% [markdown]
# Компания проводит отбор кандидатов, но не разглашает способ отбора.
#
# $H_0$ — слабый кандидат, $H_1$ — сильный кандидат.
#
# Известно, что уровень значимости $0.001$, а мощность $0.07$.

# %% [markdown]
# ##1. (red, баллы: 0.6) Кандидата Ивана взяли на работу.
#
#   Есть ли уверенность, что Иван сильный кандидат? На какой характеристике теста она основана?

# %% [markdown]
# **Решение**

# %% [markdown]
# ##2. (red, баллы: 0.6) Кандидата Антона не взяли на работу.
#
#   Есть ли уверенность, что Антон слабый кандидат? На какой характеристике теста она основана?

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 7. Продумай серию тестов

# %% [markdown]
# Требуется, чтобы у серии из 10 тестов уровень значимости был не больше 10%. В каждом тесте серии выбирается одинаковый уровень значимости $\alpha$.

# %% [markdown]
# ##1. (red, баллы: 1) Если результаты тестов независимы, какой максимальный уровень значимости $\alpha$ можно взять в одиночном тесте серии?

# %% [markdown]
# **Решение**

# %% [markdown]
# ##2. (black, баллы: 1.5) Если результаты тестов необязательно независимы, какой максимальный уровень значимости $\alpha$ можно взять в одиночном тесте серии?

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 8. Придумай тест

# %% [markdown]
# Инженеры собрали прибор, который при наведении мгновенно показывает для каждого человека число $X$. Известно, что для пьяных и трезвых водителей распределение $X$ разное.
#
#   <table>
# <caption>
# Распределение $X$ - показаний прибора.
# </caption>
#   <thead>
#     <tr>
#       <th>Возможные значения на приборчике: $k$</th>
#       <th>$0$</th>
#       <th>$1$</th>
#       <th>$2$</th>
#       <th>$3$</th>
#       <th>$4$</th>
#       <th>$5$</th>
#       <th>$6$</th>
#       <th>$7$</th>
#       <th>$8$</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><b>Среди трезвых водителей: $P(X=k)$</b></td>
#       <td>$0.01$</td>
#       <td>$0.03$</td>
#       <td>$0.25$</td>
#       <td>$0.49$</td>
#       <td>$0.03$</td>
#       <td>$0.07$</td>
#       <td>$0.09$</td>
#       <td>$0.02$</td>
#       <td>$0.01$</td>
#     </tr>
#     <tr>
#       <td><b>Среди пьяных водителей: $P(X=k)$</b></td>
#       <td>$0.06$</td>
#       <td>$0.20$</td>
#       <td>$0.12$</td>
#       <td>$0.10$</td>
#       <td>$0.30$</td>
#       <td>$0.03$</td>
#       <td>$0.02$</td>
#       <td>$0.12$</td>
#       <td>$0.05$</td>
#     </tr>
#   </tbody>
# </table>
#
# Дилемма: отправлять ли водителя в медицинскую лабораторию на освидетельствование или отпускать в путь за рулём.

# %% [markdown]
# ##1. (black, баллы: 1) Сформулируй $H_0$ и $H_1$ и объясни почему.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##2. (black, баллы: 1.2) Найди наилучший тест с уровнем значимости 1%.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##3. (black, баллы: 1.2) Найди оптимальный тест с уровнем значимости 2%.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##4. (black, баллы: 1.2) Найди оптимальный тест с уровнем значимости 3%.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##5. (black, баллы: 1.2) Найди оптимальный тест с уровнем значимости 5%.

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 9. Предложи тестовую статистику

# %% [markdown]
# Чтобы разработать тест, нужна тестовая статистика. Причём чем сильнее отличаются распределения этой статистики, когда верна $H_0$ и когда верна $H_1$, тем лучшего соотношения уровня значимости и мощности удастся добиться для теста.
#
# Доходность акции в день обозначим за $X$.
#
# Рассматривается пара гипотез:
#
# - $H_0$ — разброс значений доходности маленький (стабильная доходность).
#
# - $H_1$ — разброс значений доходности большой (нестабильная доходность).
#
# Тест должен опираться на данные выборки $X_1,X_2,\dots,X_n$.
#
# ##(black, баллы: 1.5) Предложи тестовую статистику, функцию от наблюдений $f(X_1,X_2,\dots,X_n)$ и объясни без вычислений, как будет отличаться её поведение, когда верна $H_0$, и когда верна $H_1$.
#
# *Примечание: решение очень-очень не единственно!*

# %% [markdown]
# **Решение**
