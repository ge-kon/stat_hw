# %%
import pandas as pd, numpy as np, scipy.stats as sps, matplotlib.pyplot as plt
import statsmodels.stats.proportion as smp

# %% [markdown]
# # Задача 1. Проведи тесты

# %% [markdown]
# В выборке 400 клиентов в сегменте $A$ средняя выручка составила 340 рублей, а стандартное отклонение — 50 рублей. В выборке 200 клиентов сегмента $B$ средняя выручка составила 360 рублей, а стандартное отклонение — 100 рублей. Можно считать, что выборки случайные и независимые.
#
# При проведении тестов обязательно:
# - Выпиши нулевую и альтернативную гипотезы, уточнив, идёт ли в них речь о средней выручке по выборке или по всему сегменту.
# - Найди p-value и сделай вывод об отклонении или неотклонении $H_0$.
# - Сделай содержательный вывод в контексте задачи.
# - Используй уровень значимости 5%.

# %% [markdown]
# ##1. (blue, баллы: 1) Можно ли утверждать статистически значимо, что средняя выручка во всём сегменте $A$ выше 350 рублей?

# %% [markdown]
# **Решение**

# %% [markdown]
# ##2. (blue, баллы: 1) Если ли статистически значимая разница между средней выручкой в сегменте $B$ и 350 рублями?

# %% [markdown]
# **Решение**

# %% [markdown]
# ##3. (blue, баллы: 1) Если ли статистически значимая разница между средней выручкой в сегменте $A$ и в сегменте $B$?

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 2. Объясни, почему неверно выбирать способ теста постфактум

# %% [markdown]
# Для тестирования гипотез $H_0: \mu =100$, $H_1:\mu\ne100$ предлагается алгоритм:

# %%
def my_test(sample_size, sample_mean, sample_std):
    if sample_mean > 100:
        return ztest_1sample(pop_mean=100, sample_mean, sample_std, sample_size, alternative='greater'):
    else:
        return ztest_1sample(pop_mean=100, sample_mean, sample_std, sample_size, alternative='less'):

def correct_test(sample_mean, sample_std, sample_size):
    return ztest_1sample(pop_mean=100, sample_mean, sample_std, sample_size, alternative='two-sided'):

# Считай, что функция ztest_1sample возвращает статистику и p-value соответствующего теста для среднего.

# %% [markdown]
# ##1. (blue, баллы: 2) Объясни, почему p-value, найденное с помощью `my_test`, приведёт к неверным выводам о статистической значимости.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##2. (red, баллы: 0.5) Как скорректировать p-value, найденное с помощью `my_test`, чтобы оно совпадало с правильным, найденным с помощью `correct_test`?

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 3. Найди мощность и минимально детектируемый эффект

# %% [markdown]
# Во всех пунктах можно использовать метод Монте-Карло, генерируя данные из нормального распределения. В каждом отдельном тесте выбирай уровень значимости равным 5%.

# %% [markdown]
# ##1. (blue, баллы: 1.5) Найди мощность z-теста $H_0:\mu=400$, $H_1: \mu\ne 400$.
#
#   Случайная выборка размера 200 наблюдений из распределения $\mathcal{N}(\mu,\sigma^2)$.
#
#   Найди мощность z-теста при $\mu=450$, $\sigma=100$ и проинтерпретируй найденное число.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##2. (red, баллы: 1) Построй график мощности z-теста $H_0:\mu=400$, $H_1: \mu\ne 400$.
#
#  Cлучайная выборка размера 200 наблюдений из распределения $\mathcal{N}(\mu,\sigma^2)$ при фиксированной $\sigma=100$.
#
#  Построй график мощности z-теста при разных эффектах на среднее. Найди минимально детектируемый эффект.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##3. (red, баллы: 1) Выполни предыдущий пункт, сравнив на одном графике мощности для $\sigma=100$, $\sigma=200$. Как изменился минимально детектируемый эффект?

# %% [markdown]
# **Решение**

# %% [markdown]
# ##4. (red, баллы: 1) Построй график мощности z-теста $H_0:\mu_A=\mu_B$, $H_1: \mu_A\ne \mu_B$.
#
#   Независимые случайные выборки размера 200 и 300 наблюдений из распределений $\mathcal{N}(\mu_A,\sigma_A^2)$ и $\mathcal{N}(\mu_B,\sigma_B^2)$, при $\sigma_A=100$,$\sigma_B=200$.
#
#   Построй график мощности z-теста в зависимости от эффекта $\mu_A-\mu_B$. Меняется ли зависимость мощности от эффекта при изменении значения $\mu_A$?

# %% [markdown]
# **Решение**

# %% [markdown]
# ##5. (black, баллы: 2) Найди минимально необходимый размер выборки.
#
#   Размер выборки должен позволять с вероятностью 80% обнаруживать эффект $+10$ к среднему с помощью z-теста гипотезы $H_0:\mu=400$, $H_1:\mu\ne400$. Найди ответ для $\sigma=100$, $\sigma=200$ и прокомментируй.

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 4. Проведи тесты на данных из кейса «Золотая жила 2»

# %% [markdown]
# Датасет [golden_mine.csv](https://raw.githubusercontent.com/zalig/cu-datasets/main/golden_mine.csv) содержит данные кейса [«Золотая жила 2»(TODO: добавить ссылку на слайды кейса)](https://), в котором нужно с помощью датасета найти наиболее прибыльные категории клиентов — пользователей
# платформы для изучения иностранного языка.
#
# Описание столбцов датасета:
#
# - Gender — пол клиента;
# - Age — возраст клиента в годах;
# - Age Group — возрастная группа;
# - Payments — общая сумма платежей от игрока в рублях за всё время существования платформы;
# - Costs — себестоимость оказанных клиенту услуг в рублях за всё время существования платформы;
# - Profit — разница между Payments и Costs.
#
# Стоимость привлечения нового клиента — 15000 рублей.
# Считай, что текущие клиенты — это выборка из всех возможных клиентов.
#
# Если тесты проводятся серией, используй 5% уровень значимости для всей серии. Для определения минимально детектируемого эффекта  используй мощность 80%.

# %% [markdown]
# ##1. (blue, баллы: 1.1) Найди среднюю прибыль от привлечения клиента без таргетирования и проверь, что она статистически значимо больше нуля. Прокомментируй также экономическую значимость.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##2. (blue, баллы: 1.2) Для двух категорий клиентов: «Мужчины 18-24 лет» и «Женщины 18-24 лет» проверь статистическую значимость разницы между ними в прибыльности. Прокомментируй также экономическую значимость.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##3. (blue, баллы: 1.2) Проведи тесты значимости прибыльности привлечения клиентов в каждой из двух категорий «Мужчины 18-24 лет» и «Женщины 18-24 лет» по отдельности. На каком уровне значимости сделаны выводы?

# %% [markdown]
# **Решение**

# %% [markdown]
# ##4. (red, баллы: 0.5) Проведи тесты значимости прибыльности привлечения клиентов в каждой из двух категорий «Женщины 18-21 лет» и «Женщины 22-24 лет» по отдельности, определи статистическую значимость разницы между категориями. Объясни выбор уровня значимости.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##5. (red, баллы: 0.5) Прокомментируй идею сравнивать подкатегории «Женщины 18 лет», «Женщины 19 лет», «Женщины 20 лет», ... «Женщины 24 лет», попарно тестируя значимость разницы в прибыльности:
#   - Как придётся выбирать уровень значимости? Почему нельзя взять 5% на каждый тест?
#   - Что произойдёт с минимальным детектируемым эффектом? Качественного ответа достаточно.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##6. (black, баллы: 2) Определи минимальный детектируемый эффект в тесте, проверяющем, что прибыль в категории «Мужчины 18 лет» выше стоимости привлечения.
# Определи минимальный детектируемый эффект в серии тестов, проверяющих, что прибыль хотя бы в одной из категорий в категории «Мужчины 18 лет», «Мужчины 19 лет», ... «Мужчины 24 лет» выше стоимости привлечения. Не забывай про корректировку уровня значимости.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##7. (black, баллы: 1.5) Проверь значимость разницы в прибыльности категории «Золотая жила» (найдена в кейсе-1) и категории «Женщины 18-24 лет».

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 5. Проведи и исследуй незнакомый тест «из интернета»

# %% [markdown]
# ##1. (red, баллы: 0.5) Проведи на 5% уровне значимости [JB-тест](https://ru.wikipedia.org/wiki/%D0%A2%D0%B5%D1%81%D1%82_%D0%A5%D0%B0%D1%80%D0%BA%D0%B5_%E2%80%94_%D0%91%D0%B5%D1%80%D0%B0) в Python:  `_, jb_pvalue = sps.jarque_bera(data)`.
#
#   Используй данные столбца T из датасета с выборкой пользователей приложения [time_mobile_app.csv](https://raw.githubusercontent.com/zalig/cu-datasets/main/06_time_mobile_app.csv). Здесь T — время, проведённое клиентом в мобильном приложении в часах.
#
#   Не забудь указать нулевую и альтернативную гипотезу, найти p-value, сделать вывод от отклонении или не отклонении гипотезы и вывод по смыслу.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##2. (black, баллы: 1.5) Исследуй работу теста на нормальном распределении методом Монте-Карло. Для этого:
#  - запусти тест на 5% уровне значимости на сгенерированных данных из распределения $\mathcal{N}(\mu,\sigma)$ при разных $\mu$ и $\sigma$;
#  - проинтерпретируй результаты;
#  - сделай выводы.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##3. (black, баллы: 1.5) Исследуй работу теста на равномерном распределении методом Монте-Карло. Для этого:
#  - запусти тест на 5% уровне значимости на сгенерированных данных из распределения $Uniform[0;b]$ при разных $b$, используя `sps.uniform.rvs(scale=b,...)`;
#  - проинтерпретируй результаты;
#  - сделай выводы.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##4. (black, баллы: 1.5) Исследуй работу теста на экспоненциальном распределении методом Монте-Карло. Для этого:
#  - запусти тест на 5% уровне значимости на сгенерированных данных из распределения $Exponential(mean=m)$ при разных $m$ используя `sps.expon.rvs(scale=m,...)`;
#  - проинтерпретируй результаты;
#  - сделай выводы.

# %% [markdown]
# **Решение**
