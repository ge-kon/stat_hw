# %%
import pandas as pd, numpy as np, scipy.stats as sps, matplotlib.pyplot as plt
import statsmodels.stats.proportion as smp

# %% [markdown]
# # Задача 1. Проведи тест

# %% [markdown]
# Чтобы пройти первый этап отбора в компанию, кандидат проходит тест из 15 задач. Они случайно выбираются из огромного банка задач.
#
# Кандидат, правильно решающий задачу с вероятностью 70%, считается слабым. С большей вероятностью — сильным. На первом этапе приходит очень много слабых кандидатов, важно пропустить на следующий этап не более 3% из них.
#
# ##1. (blue, баллы: 0.2) Сформулируй $H_0$ и $H_1$ и математически, и по смыслу, объясни выбор $H_0$ и $H_1$.
#
# ##2. (blue, баллы: 0.4) Выбери уровень значимости, на котором будет проводиться тест статистической значимости. Опираясь на постановку задачи, объясни, почему именно этот уровень значимости выбран.
#
# ##3. (blue, баллы: 0.2) Назови тест, который будешь проводить.
#
# ##4. (blue, баллы: 0.4) Анна правильно решила 12 задач в отборочном тесте. Проведи статистический тест на значимость:
#  - найди p-value,
#  - с помощью p-value сделай вывод о статистической значимости,
#  - сделай смысловой вывод об Анне в контексте задачи.
#
# ##5. (blue, баллы: 0.4) Борис правильно решил 14 задач. Проведи тест статистической значимости:
#  - найди p-value,
#  - с помощью p-value сделай вывод о статистической значимости,
#  - сделай смысловой вывод о Борисе в контексте задачи.
#
# ##6. (blue, баллы: 0.4) Виктория правильно решила 15 задач. Проверь статистическую значимость:
#  - найди p-value,
#  - с помощью p-value сделай вывод о статистической значимости,
#  - сделай смысловой вывод о Виктории в контексте задачи.
#
# ##7. (blue, баллы: 0.4) Какому порогу соответствует тест с требуемым уровнем значимости? Иными словами, при каком минимальном числе правильных ответов нулевая гипотеза будет отвергнута?
#
# ##8. (red, баллы: 0.8) Учитывая найденный в предыдущем пункте порог, на каком уровне значимости на самом деле проводится тест? Проинтерпретируй найденное число.
#
# ##9. (red, баллы: 0.5) Найди мощность теста для экономического эффекта «вероятность решить задачу в тесте на 10% выше, чем у слабого кандидата». Проинтерпретируй найденное число.
#
# ##10. (red, баллы: 0.5) Найди мощность теста для экономического эффекта «вероятность решить задачу в тесте на 20% выше, чем у слабого кандидата». Проинтерпретируй найденное число.
#
# ##11. (black, баллы: 1) Найди (можно подбором) минимальный детектируемый эффект на 80% мощности теста. Проинтерпретируй найденный эффект.
#
# ##12. (black, баллы: 2) Эффективно ли устроен отборочный тест? Что можно было бы изменить в отборочном тесте, чтобы достичь минимально детектируемого эффекта в 10%?

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 2. Прокомментируй выбор одностороннего или двустороннего теста

# %% [markdown]
# ##1. (blue, баллы: 0.2) Был ошибочно проведён двусторонний тест. Объясни, в чём проблема.
#
#   В условиях предыдущей задачи про отбор кандидатов аналитики зачем-то стали проводить двусторонний тест. У Геннадия p-value теста оказалось $\approx 0.0247$.
#
#   Объясни, почему на основе p-value данного теста неясно, какое решение принимать относительно Геннадия.
#
# ##2. (blue, баллы: 0.2) Сформулируй $H_0$ и $H_1$ теста.
#
#   Текущий дизайн веб-страницы даёт конверсию посетителей в продажи 5%. Новый дизайн тестируется: его конверсия $p$ неизвестна, но вскоре будет получена выборочная конверсия $\hat{p}$.
#
#   Сформулируй $H_0$ и $H_1$ теста, после проведения которого p-value позволит принять решение, менять текущий дизайн на новый или нет.
#
# ##3. (blue, баллы: 0.2) Сформулируй $H_0$ и $H_1$ теста.
#
#   Тестируются два дизайна $C$ и $D$, их конверсии $p_C$ и $p_D$ неизвестны. После получения выборочных конверсий необходимо проверить статистическую значимость их различия.
#
#    Сформулируй $H_0$ и $H_1$ теста, после которого p-value позволит решить, есть ли разница в дизайнах с точки зрения конверсии.

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 3. Погрузись в смыслы уровня значимости

# %% [markdown]
# Продолжение задачи 1.

# %% [markdown]
# ##1. (blue, баллы: 0.3) Прокомментируй выводы из p-value на нескольких уровнях значимости.
#
#   Для Анны p-value = 0.2968. На уровне значимости 3% получается один вывод статистического теста, а на уровне значимости 40% — противоположный вывод.
#
#   Проинтерпретируй оба вывода. Можно опираться на следующий шаблон: «Если компания готова..., то результаты Анны статистически значимо выше результатов слабого кандидата, и её нужно пропустить на второй этап отбора, а если компания готова..., то..., и Анну на второй этап пропускать нельзя».
#
# ##2. (red, баллы: 0.8) Найди настоящий уровень значимости в серии статистических тестов.
#
#   Пусть кандидататам разрешено проходить отборочный тест первого этапа многократно. Лимит — 1 раз в день. Каждая попытка прохождения — новые 15 задач из большого банка неповторяющихся задач. Пусть порог для прохождения во второй этап — 15 задач. Иными словами, нулевая гипотеза отвергается, если кандидат правильно решил все 15 задач из 15.
#
#   Каков уровень значимости за 1 день?
#
#   Каков уровень значимости за 30 дней?
#
#   Проинтерпретируй найденные уровни значимости:
#   «Среди ... при однократном решении отборочного теста во второй этап пройдут...» и аналогично для 30 дней.

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 4. Проведи тест

# %% [markdown]
# 1. (blue, баллы: 0.4) Проверь статистическую значимость разницы конверсий.
#
#   Из 1200 посетителей веб-страницы $A$ 7 совершили покупку, а из 890 посетителей веб-страницы $B$ 5 совершили покупку. Проверь статистическую значимость разницы конверсий страниц $A$ и $B$.
#
# 2. (blue, баллы: 0.4) Проверь статистическую значимость изменения конверсии.
#
#   Основной дизайн имеет конверсию 2%. Изменённый дизайн страницы показал следующий результат: из 1200 посетителей 7 совершили покупку. Проверь статистическую значимость изменения конверсии (в том числе в худшую сторону).
#
# 3. (blue, баллы: 0.4) Проверь статистическую значимость увеличения конверсии.
#
#   Основной дизайн имеет конверсию 2%. Изменённый дизайн страницы показал следующий результат: из 1200 посетителей 7 совершили покупку. Проверь статистическую значимость увеличения конверсии.

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 5. Проведи тесты на данных из кейса «Рекламщики 2»

# %% [markdown]
# Датасет [advertisment.csv](https://raw.githubusercontent.com/zalig/cu-datasets/main/advertisment.csv) содержит данные кейса [«Рекламщики 2»(TODO: добавить ссылку на слайды кейса)](https://).
#
# У сети поликлиник в базу 20 тысяч клиентов. Новая услуга «Спасение от усталости» приносит прибыль 3000 рублей с покупателя.
# Креативный отдел предложил два варианта рекламных кампаний (РК):
# 1. Вариант А.
# 2. Вариант B.
#
# Проведён тестовый запуск кампаний на небольшом числе клиентов. Себестоимость рекламы на 1 клиента — 80 рублей в каждом варианте.
#
# В датасете данные о 20 тысячах клиентов сети поликлиник:
# год рождения, пол, год с которого стал клиентом, участвавал ли в рекламных кампаниях A или B, купил ли услугу «Спасение от усталости».
#
# Экономически значимым эффектом считай повышение прибыли на 300 тысяч рублей.
# При тестировании гипотез используй уровень значимости 5%.
# При определении минимально-детектируемого эффекта используй мощность 80%.
#
# Считай всех клиентов генеральной совокупностью, а участников тестовых запусков — независимыми выборками. Клиентов, не участвовавших ни в одной из тестовых рекламных кампаний, подавляющее большинство. Назовём их контрольной группой, а конверсию среди них — естественной конверсией. Считай её не выборочной, а конверсией в генеральной совокупности.

# %% [markdown]
# ##1. (blue, баллы: 0.5) Проведи тест значимости разницы конверсий между рекламными кампаниями A и B.
#
# ##2. (blue, баллы: 0.5) Найди естественную конверсию.
#
# ##3. (blue, баллы: 0.5) Проверь, что A значимо повышает конверсию по сравнению с естественным уровнем.
#
# ##4. (blue, баллы: 0.5) Проверь, что B значимо повышает конверсию по сравнению с естественным уровнем.
#
# ##5. (blue, баллы: 0.5) Прокомментируй выбор уровня значимости в каждом из предыдущих тестов, если требуется значимость 5% для всей серии тестов.
#
# ##6. (blue, баллы: 0.8) Построй распределение по полу:
#  - среди всех клиентов,
#  - среди участников A,
#  - среди участников B.
#
# ##7. (blue, баллы: 0.8) Построй распределение по возрасту, разбив клиентов на 2 категории: «до 23» и «23+»:
#  - среди всех клиентов,
#  - среди участников A,
#  - среди участников B.
#
# ##8. (blue, баллы: 0.8) Построй распределение по дате регистрации клиента: давний (с прошлого года) и недавний (с этого года):
#  - среди всех клиентов,
#  - среди участников A,
#  - среди участников B.
#
# ##9. (blue, баллы: 0.6) Прокомментируй предположения предыдущих тестов: можно ли доверять результатам.

# %% [markdown]
# ##10. (red, баллы: 0.8) Расчитай экономически значимое повышение конверсии.
#
#   Насколько конверсия РК должна быть выше естественной конверсии, чтобы это было экономически значимо (повышение прибыли на 300 тысяч рублей)?
#
#   Для расчёта прибыли учитывай стоимость рекламной компании и прибыль от дополнительных покупок. Дополнительные покупки считай так:
#    - РК будет показана только клиентам, которые не участвовали ни в одной из тестовых РК.
#    - Можно считать, что среди них дополнительная конверсия составит $p-p_0$, где $p_0$ — естественная конверсия в генеральной совокупности, а $p$ — конверсия РК  в генеральной совокупности.
#
# ##11. (red, баллы: 0.8) Укажи, с какой вероятностью тест детектирует экономически значимое повышение конверсии на выборках тех размеров, которые использовались для тестовых РК. Считай тест одиночным (не частью серии тестов) с уровнем значимости 5%.
#
# ##12. (red, баллы: 0.8) Опиши, как лучше собирать данные в следующих запусках тестовых рекламных компаний, чтобы тесту эффективности можно было доверять.

# %% [markdown]
# ##13. (black, баллы: 1) Теперь считай, что у РК конверсий две: среди недавних клиентов $p_{new}$, которые присоединились в этом году, и среди давних клиентов $p_{old}$, которые присоединились в прошлом году. Найди естественные конверсии $p_{0,new}$, $p_{0,old}$ для тех же сегментов.
#
#   Сделай прогноз прибыли от РК на основе двух конверсий $p_{new}$ и $p_{old}$:
#   - РК будет показана только клиентам, которые не участвовали ни в одной из тестовых РК.
#   - Дополнительные клиенты придут за счёт повышения конверсии на $p_{new}-p_{0,new}$ и $p_{old}-p_{0,old}$ соответственно.
#
# ##14. (black, баллы: 1) Проведи тест значимости положительной прибыли от каждой РК в каждом сегменте. Учитывай, что для тестирования РК используется серия из двух тестов, и уровень значимости всей серии должен быть 5%.
#
# ##15. (black, баллы: 1) Определи минимально детектируемый предыдущим тестом эффект в терминах конверсии и в терминах прибыли. Является ли он экономически значимым?
#
# ##16. (black, баллы: 2) Предложи, для кого и какую рекламную кампанию проводить. Сделай более точный прогноз дополнительных покупок и прибыли от РК.

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 6. Найди детектируемый эффект и размер выборки

# %% [markdown]
# Пусть $H_0:p=0.10$, $H_1:p>0.10$, где $p$ — конверсия. Требуется мощность 80% на 5% уровне значимости.
#
# ##1. (black, баллы: 1) При $n=1000$ найди минимально детектируемый эффект.

# %% [markdown]
# ##2. (black, баллы: 1) Найди минимальный размер выборки для детектирования эффекта повышения конверсии на $0.04$.

# %% [markdown]
# **Решение**
