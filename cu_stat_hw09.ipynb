# %%
#@title Исходники для корректного отображения условий задач (не меняйте содержимое)
import scipy.stats as sps
import matplotlib.pyplot as plt
import pandas as pd
import plotly.graph_objects as go
import numpy as np
from ipywidgets import interact, interactive, widgets
from IPython.display import display, Math, Latex
import plotly.io as pio
pio.renderers.default = 'colab'
from google.colab import output
output.enable_custom_widget_manager()
def show_pdf_with_area_below(pdf, xlim, ylim, interval, graph_size=[600,400]):
    a_input = widgets.BoundedFloatText(value=interval[0], min=xlim[0],
                                      max=xlim[1], description=r'a:',
                                      disabled=False, layout={'width': '80px'},
                                      style={'description_width': 'initial'})
    b_input = widgets.BoundedFloatText(value=interval[1], min=xlim[0],
                                      max=xlim[1], description='b:',
                                      disabled=False, layout={'width': '80px'},
                                      style={'description_width': 'initial'})
    def label_prob():
        display(Math(r'$P(a \leqslant X \leqslant b)\quad$'))
    label = widgets.interactive_output(label_prob,{})

    fig = go.Figure()
    fig.add_trace(go.Scatter(
        x=[xlim[0], xlim[1]],
        y=[0, 0],
        fill='tozeroy',
        fillcolor='rgba(0,0,255,0.3)',
        line_color='rgba(0,0,255,0.3)',
        name="",
        showlegend=False,
        hoverinfo='skip'
    ))
    fig.add_trace(go.Scatter(
        x=np.linspace(xlim[0], xlim[1], 1000), y=pdf(np.linspace(xlim[0], xlim[1], 1000)), mode='lines', name='pdf(x)',
        line_color='rgba(100,100,100,1)',
        showlegend=True
    ))
    fig.update_layout(
        xaxis_range=[xlim[0], xlim[1]],
        yaxis_range=[ylim[0], ylim[1]],
        xaxis_title='x',
        yaxis_title='pdf(x)',
        width=graph_size[0],
        height=graph_size[1],
        plot_bgcolor='white',
        modebar_remove=["autoscale", "zoom", "pan", "zoomin", "zoomout", "reset", "resetscale","toimage"],
        hovermode="x",
        xaxis_fixedrange=True, yaxis_fixedrange=True,
        margin=dict(t=40), showlegend=False,
    )

    def update_figure(a, b):
        if (a < b):
            fig.data[0].x = np.linspace(a, b, 1000)
            fig.data[0].y = pdf(np.linspace(a, b, 1000))
            fig.data[0].visible = True
        else:
            fig.data[0].x = np.linspace(a, b, 1000)
            fig.data[0].y = pdf(np.linspace(a, b, 1000))
            fig.data[0].visible = False
        fig.update_layout(
            title_text=rf'$\text{{График плотности (pdf). Вероятность }}P({a}\leqslant X \leqslant {b})$',
            title_x=0.15,
            title_xref="container",
            # title_xanchor="center"
        )
        fig.show(config= {'displaylogo': False, 'displayModeBar': False})

    out = widgets.interactive_output(update_figure, {'a': a_input, 'b': b_input})
    box_layout = widgets.Layout(display='flex', flex_flow='row', align_items='center')
    return widgets.VBox([widgets.HBox([label, a_input, b_input], layout=box_layout), out])

# %% [markdown]
# # Задача 1. Построй графики плотности нормального распределения

# %% [markdown]
# ##1. (blue, баллы: 0.7) Сумма чека $X$ в кафе моделируется в рублях с помощью нормального распределения со средним 500 рублей и стандартным отклонением 100 рублей. Коротко: $X\sim\mathcal{N}(500,100^2)$.
#
# - Построй график плотности распределения $X$ в этой модели.
#
# - На графике отметь вертикалями значения $X$:
#
#   - $\mu-3\sigma$,
#   - $\mu$,
#   - $\mu+3\sigma$.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##2. (blue, баллы: 0.7) Построй на одном графике плотности распределения разных моделей:
# - $\mathcal{N}(500,100^2)$,
# - $\mathcal{N}(700,100^2)$,
# - $\mathcal{N}(700,40^2)$.

# %% [markdown]
# **Решение**

# %% [markdown]
# ## 3. (blue, баллы: 1.8) В общем случае для плотности нормального распределения $\mathcal{N}(\mu,\sigma^2)$ дополни предложения.
#
# - Почти вся площадь (99.7%) сосредоточена между значениями ... и ... .
# - Чем больше $\mu$, тем график плотности ... .
# - Чем меньше $\sigma$, тем график плотности ... .
# - Чтобы определить значение $\mu$, на графике плотности нужно найти самую ... точку и взять её координату по ... .
# - Чтобы приблизительно определить значения $\mu-3\sigma$ и $\mu+3\sigma$, на графике плотности нужно ... .
# - Чтобы приблизительно определить значение $\sigma$, на графике плотности нужно ... .

# %% [markdown]
# **Решение**

# %% [markdown]
# ##4. (blue, баллы: 0.7) По графику плотности нормального распределения приблизительно определи $\mu$ и $\sigma$.

# %% [markdown]
# ![hw09_1.4.svg](data:image/svg+xml;base64,...)

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 2. Проведи расчёты с помощью нормальной вероятностной модели

# %% [markdown]
# Сумма чека $X$ в кафе моделируется в рублях с помощью нормального распределения со средним 500 рублей и стандартным отклонением 100 рублей. Коротко: $X\sim\mathcal{N}(500,100^2)$. С помощью модели сделай прогнозы.

# %%
show_pdf_with_area_below(pdf=sps.norm(500,100).pdf, xlim=[0,1000], ylim=[0,0.0043], interval=[300,450], graph_size=[600,400])

# %% [markdown]
# ##1. (blue, баллы: 0.7) С какой вероятностью чек окажется меньше 100 рублей?

# %% [markdown]
# **Решение**

# %% [markdown]
# ##2. (blue, баллы: 0.7) Среди всех возможных чеков как часто чек окажется больше 600 рублей?

# %% [markdown]
# **Решение**

# %% [markdown]
# ##3. (blue, баллы: 0.7) Среди всех возможных чеков какая доля попадёт в промежуток от 250 до 750 рублей?

# %% [markdown]
# **Решение**

# %% [markdown]
# ##4. (blue, баллы: 0.7) Найди такую сумму $M$ рублей, что 95% чеков меньше этой суммы (95% процентную точку).

# %% [markdown]
# **Решение**

# %% [markdown]
# ##5. (blue, баллы: 0.7) Найди такие суммы $A$ и $B$ рублей, что только 2.5% чеков меньше $A$ рублей и 2.5% чеков больше $B$ рублей. Какая доля чеков согласно модели окажется от $A$ до $B$ рублей?

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 3. Предложи нормальную модель для датасета

# %% [markdown]
# Датасет [golden_mine.csv](https://raw.githubusercontent.com/zalig/cu-datasets/main/golden_mine.csv) содержит данные для кейса [«Золотая жила»](https://raw.githubusercontent.com/zalig/cu-datasets/main/case_1_golden_mine.pdf), знакомого ещё с первого домашнего задания.
#
# Оставь в датасете только клиентов категории «Женщины 18-24 лет». Остальные наблюдения удали. Считай датасет генеральной совокупностью.
#
# ##1. (blue, баллы: 0.5) Построй гистограмму распределения прибыли в генеральной совокупности.

# %% [markdown]
# **Решение**

# %% [markdown]
# Попробуем заменить модель генеральной совокупности из датасета на модель нормального распределения $\mathcal{N}(\mu,\sigma)$ с двумя параметрами $\mu$ и $\sigma$.
#
# ##2. (blue, баллы: 0.7) С помощью гистограммы приблизительно найди параметры $\mu$ и $\sigma$.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##3. (blue, баллы: 0.7) По датасету найди среднее и смещённое стандартное отклонение в генеральной совокупности и сравни с приблизительными значениями, полученными в предыдущем пункте.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##4. (blue, баллы: 0.7) Построй на одном графике и сравни:
#  - гистограмму плотности распределения прибыли в генеральной совокупности,
#  - график плотности нормального распределения с параметрами, найденными выше.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##5. (red, баллы: 0.4) Найди долю клиентов категории «Женщины 18-24 лет» с прибылью ниже 30 тысяч рублей, используя:
#  - генеральную совокупность из датасета,
#  - нормальную модель.
#
# Сравни и сделай выводы.

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 4. Найди вероятность, опираясь на два нормальных распределения

# %% [markdown]
# Антон добирается на работу на метро в среднем за 44 минуты со стандартным отклонением 2 минуты. Борис доезжает до работы на автомобиле в среднем за 40 минут со стандартным отклонением 10 минут.
#
# Пусть $X$ — длительность пути Антона в минутах, а $Y$ — Бориса.
# Считай $X$ и $Y$ независимыми и нормально распределёнными случайными величинами.

# %% [markdown]
# ##1. (blue, баллы: 0.4) С какой вероятностью дорога на работу займёт больше 50 минут:
#
#   - у Антона,
#   - у Бориса?

# %% [markdown]
# **Решение**

# %% [markdown]
# ##2. (blue, баллы: 0.4) Верно ли, что в среднем Борис добирается быстрее Антона, а значит, Борис всегда добирается быстрее Антона?

# %% [markdown]
# **Решение**

# %% [markdown]
# ##3. (blue, баллы: 0.4) С какой вероятностью Борис проведёт в пути меньше времени, чем Антон?

# %% [markdown]
# **Решение**

# %% [markdown]
# ##4. (red, баллы: 0.4) С какой вероятностью Борис проведёт на 20% меньше времени в пути, чем Антон?

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 5. Проинтерпретируй z-score

# %% [markdown]
# Магазин «Вкупилл» доставляет заказы на дом. Для внутреннего учёта товары разделены на две категории: «еда» и «остальное». Траты клиента:
# - на еду $X$ тысяч рублей в месяц,
# - на остальное $Y$ тысяч рублей в месяц.
#
# Рассмотри модель $X\sim\mathcal{N}(12,3^2)$, $Y\sim\mathcal{N}(5,1.5^2)$.

# %% [markdown]
# ## 1. (red, баллы: 0.5) Найди и проинтерпретируй z-score значения и соответствующие значения cdf для клиента по имени Святослав, который тратит в месяц 19.5 тысяч рублей на еду и 5.5 тысяч рублей на остальное.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##2. (red, баллы: 0.3) Насколько редко встречаются клиенты с z-score по модулю больше 3?

# %% [markdown]
# **Решение**

# %% [markdown]
# ##3. (black, баллы: 2) Допустим, расходы на еду и остальное в месяц суммарно $X+Y$ тоже нормально распределены, причём корреляция между тратами на еду и на остальное $0.8$. Найди и проинтерпретируй z-score и cdf для клиента Святослава из пункта 1.

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 6. Сравни биномиальное и нормальное распределения

# %% [markdown]
# В этой задаче нужно сравнить два разных распределения (биномиальное и нормальное) с одинаковыми средним и дисперсией.
#
# Для пунктов 1-2 считай $n=1000$, $p=0.5$.

# %% [markdown]
# ##1. (red, баллы: 0.4) Построй гистограмму для биномиального распределения $X\sim Binomial(n,p)$ и график плотности нормального распределения $Y\sim\mathcal{N}(EX,VX)$. Здесь нет опечатки: среднее $Y$ намеренно выбирается таким же, как среднее $X$, и дисперсия $Y$ равной дисперсии $X$.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##2. (red, баллы: 0.4) Найди и сравни, насколько различаются $P(X < 470.5)$ и $P(Y < 470.5)$. Удалось ли обнаружить заметную разницу в прогнозах биномиальной и нормальной моделей при $n=1000$, $p=0.5$?

# %% [markdown]
# **Решение**

# %% [markdown]
# Для всех пунктов 3-6 считай $n=10$, $p=0.4$.
#
# ##3. (red, баллы: 0.4) Построй гистограмму для биномиального распределения $X\sim Binomial(n,p)$ и график плотности нормального распределения с такими же средним и дисперсией.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##4. (red, баллы: 0.4) Найди и сравни, насколько различаются $P(X < 3.5)$, $P(Y < 3.5)$. В какой из двух ситуаций прогнозы моделей различаются сильнее:
#  - при $n=10,p=0.4$,
#  - или при $n=1000,p=0.5$?

# %% [markdown]
# **Решение**

# %% [markdown]
# ##5. (black, баллы: 2) Найди и сравни, насколько сильно различаются $P(X \leqslant 3)$ и $P(Y \leqslant 3)$. При замене биномиальной модели с $n=10,p=0.4$ на нормальную с такими же средней и дисперсией как сильно могут измениться прогнозы вероятностей?

# %% [markdown]
# **Решение**

# %% [markdown]
# ##6. (black, баллы: 2) Построй на одном графике cdf для $X$ и для $Y$. В качестве аргумента используй не только целые значения, а все значения на отрезке от -3 до 13. При замене биномиальной модели с $n=10,p=0.4$ на нормальную с такими же средней и дисперсией как сильно могут измениться прогнозы вероятностей?

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 7. Воспользуйся стандартными моделями

# %% [markdown]
# В этой задаче нужно освоить общий принцип пользования стандартными вероятностными моделями. Для решения задачи необязательно понимать эти модели. При желании о них можно прочитать в интернете.

# %% [markdown]
# ## 1. (red, баллы: 0.3) $X\sim\chi^2(3)$, найди $P(X < 3)$. Распределение $\chi^2$ читается как «хи-квадрат распределение». [sps.chi2](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.chi2.html)

# %% [markdown]
# **Решение**

# %% [markdown]
# ##2. (red, баллы: 0.3) $X\sim\chi^2(3)$, найди такое число $a$, что $P(X > a) = 0.05$.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##3. (black, баллы: 1) $Y\sim t(3)$, найди $P(1 < Y < 2)$. Распределение $t$ читается как «распределение Стьюдента». [sps.t](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.t.html)

# %% [markdown]
# **Решение**

# %% [markdown]
# ##4. (black, баллы: 1) $K\sim Poisson(3)$, найди $P(K=4)$. Распределение называется «распределение Пуасссона». [sps.poisson](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.poisson.html)

# %% [markdown]
# **Решение**

# %% [markdown]
# ##5. (black, баллы: 2) Построй на одном графике плотность распределений:
#  - $\mathcal{N}(0,1)$,
#  - $t(3)$,
#  - $t(99999)$.
#
# Прокомментируй.

# %% [markdown]
# **Решение**
